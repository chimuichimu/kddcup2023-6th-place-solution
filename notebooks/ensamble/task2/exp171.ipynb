# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
from tqdm import tqdm

# %%
EXP_NAME = "exp171"
DIR = "/gdrive/MyDrive/amazon_kdd_2023/"
WEIGHTS = [1.0, 1.0, 1.0]

# %%
subs = {
    "exp162": DIR + "data/output/task2/exp162.parquet", # LB:0.44623
    "exp167": DIR + "data/output/task2/exp167.parquet", # LB:0.44629
    "exp168": DIR + "data/output/task2/exp168.parquet", # LB:0.44664
}

# %%
assert(len(WEIGHTS) == len(subs))

# %%
for i, n in enumerate(subs):
    path = subs[n]
    if i == 0:
        sub = pd.read_parquet(path)
        sub.columns = ['locale', 'labels0']
    else:
        sub[f'labels{i}'] = pd.read_parquet(path)['next_item_prediction']

# %%
def cust_blend(dt, W = [1,1,1,1], base=3):   
    REC = []
    for i in range(len(W)):
        REC.append(dt[f'labels{i}'])

    res = {}
    for M in range(len(REC)):
        for n, v in enumerate(REC[M]):
            if v in res:
                res[v] += (W[M]/(n+base))
            else:
                res[v] = (W[M]/(n+base))
    
    res = list(dict(sorted(res.items(), key=lambda item: -item[1])).keys())
    
    return res[:100]

# %%
sub['next_item_prediction'] = sub.apply(cust_blend, W = WEIGHTS, axis=1)

# %%
sub[["locale", "next_item_prediction"]].to_parquet(DIR + "data/output/task2/" + EXP_NAME + ".parquet", engine='pyarrow')

# %%
sub.head()
# Out:
#   locale                                            labels0  \
# 0     ES  [B074RZKWMD, B0745795KF, B074581R8Y, B07457KX2...
# 1     ES  [B09M8LNB61, B09J4T4JF5, B09NQKCQWS, B09NT33LZ...
# 2     ES  [B0B461V1RB, B0B4614XL6, B0B4643ZJN, B0B4625TR...
# 3     ES  [B07R4VG9X3, B07R4WKSSV, B07QZ35DY6, B07QXZJK8...
# 4     ES  [B09G9LF91K, B09G97SLGS, B09G9DMQ7M, B09G99D95...
#
#                                              labels1  \
# 0  [B0745795KF, B074RZKWMD, B074581R8Y, B07457KX2...
# 1  [B09M8LNB61, B09J4T4JF5, B09NQKCQWS, B09NT33LZ...
# 2  [B0B461V1RB, B0B4614XL6, B0B4643ZJN, B0B4625TR...
# 3  [B07R4VG9X3, B07R4WKSSV, B07QZ35DY6, B07QXZJK8...
# 4  [B09G9LF91K, B09G97SLGS, B09G9DMQ7M, B09G99D95...
#
#                                              labels2  \
# 0  [B074RZKWMD, B0745795KF, B07457KX2S, B074581R8...
# 1  [B09M8LNB61, B09J4T4JF5, B09NT33LZN, B09NQKCQW...
# 2  [B0B461V1RB, B0B4614XL6, B0B461KYQY, B0B4625TR...
# 3  [B07R4WKSSV, B07R4VG9X3, B07QZ35DY6, B07QXZJK8...
# 4  [B09G9LF91K, B09G99D95Q, B09G97SLGS, B09G9DMQ7...
#
#                                 next_item_prediction
# 0  [B074RZKWMD, B0745795KF, B074581R8Y, B07457KX2...
# 1  [B09M8LNB61, B09J4T4JF5, B09NQKCQWS, B09NT33LZ...
# 2  [B0B461V1RB, B0B4614XL6, B0B4643ZJN, B0B4625TR...
# 3  [B07R4VG9X3, B07R4WKSSV, B07QZ35DY6, B07QXZJK8...
# 4  [B09G9LF91K, B09G97SLGS, B09G99D95Q, B09G9DMQ7...
