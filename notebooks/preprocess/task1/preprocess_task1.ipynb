# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# !pip install polars
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: polars in /usr/local/lib/python3.9/dist-packages (0.17.3)
# Requirement already satisfied: typing_extensions>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from polars) (4.5.0)

# %%
from collections import defaultdict, Counter
from typing import List, Dict

from tqdm import tqdm
import polars as pl

# %%
train = pl.read_csv("/gdrive/MyDrive/amazon_kdd_2023/data/raw/sessions_train.csv")
test = pl.read_csv("/gdrive/MyDrive/amazon_kdd_2023/data/raw/sessions_test_task1.csv")

# %%
LOCALES = ["DE", "UK", "JP"]
train = train.filter(pl.col("locale").is_in(LOCALES))
test = test.filter(pl.col("locale").is_in(LOCALES))

# %%
# prev_itemsの加工
def str2list(s):
    s = s.replace("[", "").replace("]", "").replace("'", "").replace("\n", " ").replace("\r", " ")
    s = s.split() # 空白で区切ってリスト化
    return s

train = train.with_columns(pl.col("prev_items").apply(str2list).alias("prev_items"))
test = test.with_columns(pl.col("prev_items").apply(str2list).alias("prev_items"))

# %%
# session_idの付与
train = train.with_columns(pl.Series(name="session_id", values=["train_" + str(i) for i in range(len(train))]))
test = test.with_columns(pl.Series(name="session_id", values=["test_" + str(i) for i in range(len(test))]))

# %%
train.head()
# Out:
# shape: (5, 4)
# ┌───────────────────────────────────┬────────────┬────────┬────────────┐
# │ prev_items                        ┆ next_item  ┆ locale ┆ session_id │
# │ ---                               ┆ ---        ┆ ---    ┆ ---        │
# │ list[str]                         ┆ str        ┆ str    ┆ str        │
# ╞═══════════════════════════════════╪════════════╪════════╪════════════╡
# │ ["B09W9FND7K", "B09JSPLN1M"]      ┆ B09M7GY217 ┆ DE     ┆ train_0    │
# │ ["B076THCGSG", "B007MO8IME", … "… ┆ B001B4THSA ┆ DE     ┆ train_1    │
# │ ["B0B1LGXWDS", "B00AZYORS2", … "… ┆ B0767DTG2Q ┆ DE     ┆ train_2    │
# │ ["B09XMTWDVT", "B0B4MZZ8MB", … "… ┆ B0B4R9NN4B ┆ DE     ┆ train_3    │
# │ ["B09Y5CSL3T", "B09Y5DPTXN", "B0… ┆ B0BGVBKWGZ ┆ DE     ┆ train_4    │
# └───────────────────────────────────┴────────────┴────────┴────────────┘

# %%
test.head()
# Out:
# shape: (5, 3)
# ┌───────────────────────────────────┬────────┬────────────┐
# │ prev_items                        ┆ locale ┆ session_id │
# │ ---                               ┆ ---    ┆ ---        │
# │ list[str]                         ┆ str    ┆ str        │
# ╞═══════════════════════════════════╪════════╪════════════╡
# │ ["B08V12CT4C", "B08V1KXBQD", … "… ┆ DE     ┆ test_0     │
# │ ["B00R9R5ND6", "B00R9RZ9ZS", "B0… ┆ DE     ┆ test_1     │
# │ ["B07YSRXJD3", "B07G7Q5N6G", … "… ┆ DE     ┆ test_2     │
# │ ["B08KQBYV43", "3955350843", … "… ┆ DE     ┆ test_3     │
# │ ["B09FPTCWMC", "B09FPTQP68", … "… ┆ DE     ┆ test_4     │
# └───────────────────────────────────┴────────┴────────────┘

# %%
train.write_parquet("/gdrive/MyDrive/amazon_kdd_2023/data/preprocessed/task1/train_task1.parquet")

# %%
test.write_parquet("/gdrive/MyDrive/amazon_kdd_2023/data/preprocessed/task1/test_task1.parquet")
